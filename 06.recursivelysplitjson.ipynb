# %% [markdown]
# # 递归拆分 JSON

# %% [markdown]
# 此 json 拆分器首先遍历 json 数据深度并构建较小的 json 块。它尝试保持嵌套的 json 对象完整，但如果需要，它会拆分它们以在min_chunk_size和max_chunk_size之间保留块。如果该值不是嵌套的 json，而是一个非常大的字符串，则不会拆分该字符串。如果您需要对块大小进行硬上限，请在这些块上使用递归文本拆分器。拆分列表有一个可选的预处理步骤，首先将它们转换为 json （dict），然后将它们拆分成这样。

# %% [markdown]
# 1. 如何拆分文本：json 值。
# 2. 如何测量块大小：按字符数。

# %%
import json

import requests

# %%
from pprint import pprint

# This is a large nested json object and will be loaded as a python dict
json_data = requests.get("https://api.smith.langchain.com/openapi.json").json()
pprint(json_data)
# Out:
# {'components': {'schemas': {'APIFeedbackSource': {'description': 'API feedback '
#                                                                  'source.',
#                                                   'properties': {'metadata': {'anyOf': [{'type': 'object'},
#                                                                                         {'type': 'null'}],
#                                                                               'title': 'Metadata'},
#                                                                  'type': {'default': 'api',
#                                                                           'title': 'Type',
#                                                                           'type': 'string'}},
#                                                   'title': 'APIFeedbackSource',
#                                                   'type': 'object'},
#                             'APIKeyCreateRequest': {'description': 'API key '
#                                                                    'POST '
#                                                                    'schema.',
#                                                     'properties': {'description': {'default': 'Default '
#                                                                                               'API '
#                                                                                               'key',
#                                                                                    'title': 'Description',
#                                                                                    'type': 'string'},
#                                                                    'read_only': {'default': False,
#                                                                                  'title': 'Read '
#                                                                                           'Only',
#                                                                                  'type': 'boolean'}},
#                                                     'title': 'APIKeyCreateRequest',
#                                                     'type': 'object'},
#                             'APIKeyCreateResponse': {'description': 'API key '
#                                                                     'POST '
#                                                                     'schema.',
#                                                      'properties': {'created_at': {'anyOf': [{'format': 'date-time',
#                                                                                               'type': 'string'},
#                                                                                              {'type': 'null'}],
#                                                                                    'title': 'Created '
#                                                                                             'At'},
#                                                                     'description': {'title': 'Description',
#                                                                                     'type': 'string'},
#                                                                     'id': {'format': 'uuid',
#                                                                            'title': 'Id',
#                                                                            'type': 'string'},
#                                                                     'key': {'title': 'Key',
#                                                                             'type': 'string'},
#                                                                     'read_only': {'title': 'Read '
#                                                                                            'Only',
#                                                                                   'type': 'boolean'},
#                                                                     'short_key': {'title': 'Short '
#                                                                                            'Key',
#                                                                                   'type': 'string'}},
#                                                      'required': ['id',
#                                                                   'short_key',
#                                                                   'description',
#                                                                   'read_only',
#                                                                   'key'],
#                                                      'title': 'APIKeyCreateResponse',
#                                                      'type': 'object'},
#                             'APIKeyGetResponse': {'description': 'API key GET '
#                                                                  'schema.',
#                                                   'properties': {'created_at': {'anyOf': [{'format': 'date-time',
#                                                                                            'type': 'string'},
#                                                                                           {'type': 'null'}],
#                                                                                 'title': 'Created '
#                                                                                          'At'},
#                                                                  'description': {'title': 'Description',
#                                                                                  'type': 'string'},
#                                                                  'id': {'format': 'uuid',
#                                                                         'title': 'Id',
#                                                                         'type': 'string'},
#                                                                  'read_only': {'title': 'Read '
#                                                                                         'Only',
#                                                                                'type': 'boolean'},
#                                                                  'short_key': {'title': 'Short '
#                                                                                         'Key',
#                                                                                'type': 'string'}},
#                                                   'required': ['id',
#                                                                'short_key',
#                                                                'description',
#                                                                'read_only'],
#                                                   'title': 'APIKeyGetResponse',
#                                                   'type': 'object'},
#                             'AnnotationQueueCreateSchema': {'description': 'AnnotationQueue '
#                                                                            'schema.',
#                                                             'properties': {'created_at': {'format': 'date-time',
#                                                                                           'title': 'Created '
#                                                                                                    'At',
#                                                                                           'type': 'string'},
#                                                                            'default_dataset': {'anyOf': [{'format': 'uuid',
#                                                                                                           'type': 'string'},
#                                                                                                          {'type': 'null'}],
#                                                                                                'title': 'Default '
#                                                                                                         'Dataset'},
#                                                                            'description': {'anyOf': [{'type': 'string'},
#                                                                                                      {'type': 'null'}],
#                                                                                            'title': 'Description'},
#                                                                            'id': {'format': 'uuid',
#                                                                                   'title': 'Id',
#                                                                                   'type': 'string'},
#                                                                            'name': {'title': 'Name',
#                                                                                     'type': 'string'},
#                                                                            'updated_at': {'format': 'date-time',
#                                                                                           'title': 'Updated '
#                                                                                                    'At',
#                                                                                           'type': 'string'}},
#                                                             'required': ['name'],
#                                                             'title': 'AnnotationQueueCreateSchema',
#                                                             'type': 'object'},
#                             'AnnotationQueueRunSchema': {'properties': {'added_at': {'format': 'date-time',
#                                                                                      'title': 'Added '
#                                                                                               'At',
#                                                                                      'type': 'string'},
#                                                                         'id': {'format': 'uuid',
#                                                                                'title': 'Id',
#                                                                                'type': 'string'},
#                                                                         'last_reviewed_time': {'anyOf': [{'format': 'date-time',
#                                                                                                           'type': 'string'},
#                                                                                                          {'type': 'null'}],
#                                                                                                'title': 'Last '
#                                                                                                         'Reviewed '
#                                                                                                         'Time'},
#                                                                         'queue_id': {'format': 'uuid',
#                                                                                      'title': 'Queue '
#                                                                                               'Id',
#                                                                                      'type': 'string'},
#                                                                         'run_id': {'format': 'uuid',
#                                                                                    'title': 'Run '
#                                                                                             'Id',
#                                                                                    'type': 'string'}},
#                                                          'required': ['run_id',
#                                                                       'queue_id',
#                                                                       'id'],
#                                                          'title': 'AnnotationQueueRunSchema',
#                                                          'type': 'object'},
#                             'AnnotationQueueRunUpdateSchema': {'properties': {'added_at': {'anyOf': [{'format': 'date-time',
#                                                                                                       'type': 'string'},
#                                                                                                      {'type': 'null'}],
#                                                                                            'title': 'Added '
#                                                                                                     'At'},
#                                                                               'last_reviewed_time': {'anyOf': [{'format': 'date-time',
#                                                                                                                 'type': 'string'},
#                                                                                                                {'type': 'null'}],
#                                                                                                      'title': 'Last '
#                                                                                                               'Reviewed '
#                                                                                                               'Time'}},
#                                                                'title': 'AnnotationQueueRunUpdateSchema',
#                                                                'type': 'object'},
#                             'AnnotationQueueSchema': {'description': 'AnnotationQueue '
#                                                                      'schema.',
#                                                       'properties': {'created_at': {'format': 'date-time',
#                                                                                     'title': 'Created '
#                                                                                              'At',
#                                                                                     'type': 'string'},
#                                                                      'default_dataset': {'anyOf': [{'format': 'uuid',
#                                                                                                     'type': 'string'},
#                                                                                                    {'type': 'null'}],
#                                                                                          'title': 'Default '
#                                                                                                   'Dataset'},
#                                                                      'description': {'anyOf': [{'type': 'string'},
#                                                                                                {'type': 'null'}],
#                                                                                      'title': 'Description'},
#                                                                      'id': {'format': 'uuid',
#                                                                             'title': 'Id',
#                                                                             'type': 'string'},
#                                                                      'name': {'title': 'Name',
#                                                                               'type': 'string'},
#                                                                      'tenant_id': {'format': 'uuid',
#                                                                                    'title': 'Tenant '
#                                                                                             'Id',
#                                                                                    'type': 'string'},
#                                                                      'updated_at': {'format': 'date-time',
#                                                                                     'title': 'Updated '
#                                                                                              'At',
#                                                                                     'type': 'string'}},
#                                                       'required': ['name',
#                                                                    'id',
#                                                                    'tenant_id'],
#                                                       'title': 'AnnotationQueueSchema',
#                                                       'type': 'object'},
#                             'AnnotationQueueSizeSchema': {'description': 'Size '
#                                                                          'of '
#                                                                          'an '
#                                                                          'Annotation '
#                                                                          'Queue',
#                                                           'properties': {'size': {'title': 'Size',
#                                                                                   'type': 'integer'}},
#                                                           'required': ['size'],
#                                                           'title': 'AnnotationQueueSizeSchema',
#                                                           'type': 'object'},
#                             'AnnotationQueueUpdateSchema': {'description': 'AnnotationQueue '
#                                                                            'update '
#                                                                            'schema.',
#                                                             'properties': {'default_dataset': {'anyOf': [{'format': 'uuid',
#                                                                                                           'type': 'string'},
#                                                                                                          {'type': 'null'}],
#                                                                                                'title': 'Default '
#                                                                                                         'Dataset'},
#                                                                            'description': {'anyOf': [{'type': 'string'},
#                                                                                                      {'type': 'null'}],
#                                                                                            'title': 'Description'},
#                                                                            'name': {'anyOf': [{'type': 'string'},
#                                                                                               {'type': 'null'}],
#                                                                                     'title': 'Name'}},
#                                                             'title': 'AnnotationQueueUpdateSchema',
#                                                             'type': 'object'},
#                             'AppFeedbackSource': {'description': 'Feedback '
#                                                                  'from the '
#                                                                  'LangChainPlus '
#                                                                  'App.',
#                                                   'properties': {'metadata': {'anyOf': [{'type': 'object'},
#                                                                                         {'type': 'null'}],
#                                                                               'title': 'Metadata'},
#                                                                  'type': {'default': 'app',
#                                                                           'title': 'Type',
#                                                                           'type': 'string'}},
#                                                   'title': 'AppFeedbackSource',
#                                                   'type': 'object'},
#                             'BatchIngestConfig': {'description': 'Batch ingest '
#                                                                  'config.',
#                                                   'properties': {'scale_down_nempty_trigger': {'default': 4,
#                                                                                                'title': 'Scale '
#                                                                                                         'Down '
#                                                                                                         'Nempty '
#                                                                                                         'Trigger',
#                                                                                                'type': 'integer'},
#                                                                  'scale_up_nthreads_limit': {'default': 16,
#                                                                                              'title': 'Scale '
#                                                                                                       'Up '
#                                                                                                       'Nthreads '
#                                                                                                       'Limit',
#                                                                                              'type': 'integer'},
#                                                                  'scale_up_qsize_trigger': {'default': 1000,
#                                                                                             'title': 'Scale '
#                                                                                                      'Up '
#                                                                                                      'Qsize '
#                                                                                                      'Trigger',
#                                                                                             'type': 'integer'},
#                                                                  'size_limit': {'default': 100,
#                                                                                 'title': 'Size '
#                                                                                          'Limit',
#                                                                                 'type': 'integer'},
#                                                                  'size_limit_bytes': {'default': 20971520,
#                                                                                       'title': 'Size '
#                                                                                                'Limit '
#                                                                                                'Bytes',
#                                                                                       'type': 'integer'}},
#                                                   'title': 'BatchIngestConfig',
#                                                   'type': 'object'},
#                             'BodyParamsForRunSchema': {'description': 'Query '
#                                                                       'params '
#                                                                       'for run '
#                                                                       'endpoints.',
#                                                        'properties': {'cursor': {'anyOf': [{'type': 'string'},
#                                                                                            {'type': 'null'}],
#                                                                                  'title': 'Cursor'},
#                                                                       'end_time': {'anyOf': [{'format': 'date-time',
#                                                                                               'type': 'string'},
#                                                                                              {'type': 'null'}],
#                                                                                    'title': 'End '
#                                                                                             'Time'},
#                                                                       'error': {'anyOf': [{'type': 'boolean'},
#                                                                                           {'type': 'null'}],
#                                                                                 'title': 'Error'},
#                                                                       'execution_order': {'anyOf': [{'maximum': 1.0,
#                                                                                                      'minimum': 1.0,
#                                                                                                      'type': 'integer'},
#                                                                                                     {'type': 'null'}],
#                                                                                           'title': 'Execution '
#                                                                                                    'Order'},
#                                                                       'filter': {'anyOf': [{'type': 'string'},
#                                                                                            {'type': 'null'}],
#                                                                                  'title': 'Filter'},
#                                                                       'id': {'anyOf': [{'items': {'format': 'uuid',
#                                                                                                   'type': 'string'},
#                                                                                         'type': 'array'},
#                                                                                        {'type': 'null'}],
#                                                                              'title': 'Id'},
#                                                                       'is_root': {'anyOf': [{'type': 'boolean'},
#                                                                                             {'type': 'null'}],
#                                                                                   'title': 'Is '
#                                                                                            'Root'},
#                                                                       'limit': {'default': 100,
#                                                                                 'maximum': 100.0,
#                                                                                 'minimum': 1.0,
#                                                                                 'title': 'Limit',
#                                                                                 'type': 'integer'},
#                                                                       'order': {'allOf': [{'$ref': '#/components/schemas/RunDateOrder'}],
#                                                                                 'default': 'desc'},
#                                                                       'parent_run': {'anyOf': [{'format': 'uuid',
#                                                                                                 'type': 'string'},
#                                                                                                {'type': 'null'}],
#                                                                                      'title': 'Parent '
#                                                                                               'Run'},
#                                                                       'query': {'anyOf': [{'type': 'string'},
#                                                                                           {'type': 'null'}],
#                                                                                 'title': 'Query'},
#                                                                       'reference_example': {'anyOf': [{'items': {'format': 'uuid',
#                                                                                                                  'type': 'string'},
#                                                                                                        'type': 'array'},
#                                                                                                       {'type': 'null'}],
#                                                                                             'title': 'Reference '
#                                                                                                      'Example'},
#                                                                       'run_type': {'anyOf': [{'$ref': '#/components/schemas/RunTypeEnum'},
#                                                                                              {'type': 'null'}]},
#                                                                       'select': {'default': ['id',
#                                                                                              'name',
#                                                                                              'run_type',
#                                                                                              'start_time',
#                                                                                              'end_time',
#                                                                                              'status',
#                                                                                              'error',
#                                                                                              'extra',
#                                                                                              'events',
#                                                                                              'inputs',
#                                                                                              'inputs_s3_urls',
#                                                                                              'outputs',
#                                                                                              'outputs_s3_urls',
#                                                                                              'parent_run_id',
#                                                                                              'manifest_id',
#                                                                                              'manifest_s3_id',
#                                                                                              'session_id',
#                                                                                              'serialized',
#                                                                                              'reference_example_id',
#                                                                                              'total_tokens',
#                                                                                              'prompt_tokens',
#                                                                                              'completion_tokens',
#                                                                                              'total_cost',
#                                                                                              'prompt_cost',
#                                                                                              'completion_cost',
#                                                                                              'first_token_time',
#                                                                                              'trace_id',
#                                                                                              'dotted_order',
#                                                                                              'last_queued_at',
#                                                                                              'feedback_stats',
#                                                                                              'child_run_ids',
#                                                                                              'parent_run_ids',
#                                                                                              'tags',
#                                                                                              'in_dataset',
#                                                                                              'app_path',
#                                                                                              'share_token'],
#                                                                                  'items': {'$ref': '#/components/schemas/RunSelect'},
#                                                                                  'title': 'Select',
#                                                                                  'type': 'array'},
#                                                                       'session': {'anyOf': [{'items': {'format': 'uuid',
#                                                                                                        'type': 'string'},
#                                                                                              'type': 'array'},
#                                                                                             {'type': 'null'}],
#                                                                                   'title': 'Session'},
#                                                                       'start_time': {'anyOf': [{'format': 'date-time',
#                                                                                                 'type': 'string'},
#                                                                                                {'type': 'null'}],
#                                                                                      'title': 'Start '
#                                                                                               'Time'},
#                                                                       'trace': {'anyOf': [{'format': 'uuid',
#                                                                                            'type': 'string'},
#                                                                                           {'type': 'null'}],
#                                                                                 'title': 'Trace'},
#                                                                       'trace_filter': {'anyOf': [{'type': 'string'},
#                                                                                                  {'type': 'null'}],
#                                                                                        'title': 'Trace '
#                                                                                                 'Filter'},
#                                                                       'tree_filter': {'anyOf': [{'type': 'string'},
#                                                                                                 {'type': 'null'}],
#                                                                                       'title': 'Tree '
#                                                                                                'Filter'}},
#                                                        'title': 'BodyParamsForRunSchema',
#                                                        'type': 'object'},
#                             'Body_upload_csv_dataset_api_v1_datasets_upload_post': {'properties': {'data_type': {'allOf': [{'$ref': '#/components/schemas/DataType'}],
#                                                                                                                  'default': 'kv'},
#                                                                                                    'description': {'anyOf': [{'type': 'string'},
#                                                                                                                              {'type': 'null'}],
#                                                                                                                    'title': 'Description'},
#                                                                                                    'file': {'format': 'binary',
#                                                                                                             'title': 'File',
#                                                                                                             'type': 'string'},
#                                                                                                    'input_keys': {'items': {'type': 'string'},
#                                                                                                                   'title': 'Input '
#                                                                                                                            'Keys',
#                                                                                                                   'type': 'array'},
#                                                                                                    'name': {'anyOf': [{'type': 'string'},
#                                                                                                                       {'type': 'null'}],
#                                                                                                             'title': 'Name'},
#                                                                                                    'output_keys': {'default': [],
#                                                                                                                    'items': {'type': 'string'},
#                                                                                                                    'title': 'Output '
#                                                                                                                             'Keys',
#                                                                                                                    'type': 'array'}},
#                                                                                     'required': ['file',
#                                                                                                  'input_keys'],
#                                                                                     'title': 'Body_upload_csv_dataset_api_v1_datasets_upload_post',
#                                                                                     'type': 'object'},
#                             'Body_upload_examples_api_v1_examples_upload__dataset_id__post': {'properties': {'file': {'format': 'binary',
#                                                                                                                       'title': 'File',
#                                                                                                                       'type': 'string'},
#                                                                                                              'input_keys': {'items': {'type': 'string'},
#                                                                                                                             'title': 'Input '
#                                                                                                                                      'Keys',
#                                                                                                                             'type': 'array'},
#                                                                                                              'output_keys': {'items': {'type': 'string'},
#                                                                                                                              'title': 'Output '
#                                                                                                                                       'Keys',
#                                                                                                                              'type': 'array'}},
#                                                                                               'required': ['file',
#                                                                                                            'input_keys'],
#                                                                                               'title': 'Body_upload_examples_api_v1_examples_upload__dataset_id__post',
#                                                                                               'type': 'object'},
#                             'ChangePaymentPlanReq': {'description': 'Enum for '
#                                                                     'payment '
#                                                                     'plans '
#                                                                     'that the '
#                                                                     'user can '
#                                                                     'change '
#                                                                     'to. '
#                                                                     'Developer '
#                                                                     'plans are '
#                                                                     'permanent '
#                                                                     'and '
#                                                                     'enterprise '
#                                                                     'plans '
#                                                                     'will be '
#                                                                     'changed '
#                                                                     'manually.',
#                                                      'enum': ['disabled',
#                                                               'developer',
#                                                               'plus'],
#                                                      'title': 'ChangePaymentPlanReq',
#                                                      'type': 'string'},
#                             'ChangePaymentPlanSchema': {'description': 'Change '
#                                                                        'payment '
#                                                                        'plan '
#                                                                        'schema.',
#                                                         'properties': {'tier': {'$ref': '#/components/schemas/ChangePaymentPlanReq'}},
#                                                         'required': ['tier'],
#                                                         'title': 'ChangePaymentPlanSchema',
#                                                         'type': 'object'},
#                             'Comment': {'properties': {'comment_by': {'anyOf': [{'format': 'uuid',
#                                                                                  'type': 'string'},
#                                                                                 {'type': 'null'}],
#                                                                       'title': 'Comment '
#                                                                                'By'},
#                                                        'comment_by_name': {'anyOf': [{'type': 'string'},
#                                                                                      {'type': 'null'}],
#                                                                            'title': 'Comment '
#                                                                                     'By '
#                                                                                     'Name'},
#                                                        'comment_on': {'format': 'uuid',
#                                                                       'title': 'Comment '
#                                                                                'On',
#                                                                       'type': 'string'},
#                                                        'content': {'title': 'Content',
#                                                                    'type': 'string'},
#                                                        'created_at': {'format': 'date-time',
#                                                                       'title': 'Created '
#                                                                                'At',
#                                                                       'type': 'string'},
#                                                        'id': {'format': 'uuid',
#                                                               'title': 'Id',
#                                                               'type': 'string'},
#                                                        'liked_by_auth_user': {'anyOf': [{'type': 'boolean'},
#                                                                                         {'type': 'null'}],
#                                                                               'title': 'Liked '
#                                                                                        'By '
#                                                                                        'Auth '
#                                                                                        'User'},
#                                                        'num_likes': {'title': 'Num '
#                                                                               'Likes',
#                                                                      'type': 'integer'},
#                                                        'num_sub_comments': {'title': 'Num '
#                                                                                      'Sub '
#                                                                                      'Comments',
#                                                                             'type': 'integer'},
#                                                        'parent_id': {'anyOf': [{'format': 'uuid',
#                                                                                 'type': 'string'},
# ...
#                                                                                   'description': 'Successful '
#                                                                                                  'Response'}},
#                                                             'security': [{'API Key': []},
#                                                                          {'Tenant ID': []},
#                                                                          {'Bearer Auth': []}],
#                                                             'summary': 'Get '
#                                                                        'Current '
#                                                                        'Tenant '
#                                                                        'Usage '
#                                                                        'Limits '
#                                                                        'Info',
#                                                             'tags': ['tenant']}},
#            '/api/v1/tenants/pending': {'get': {'description': 'Get all tenants '
#                                                               'visible to this '
#                                                               'auth',
#                                                'operationId': 'list_pending_tenant_invites_api_v1_tenants_pending_get',
#                                                'responses': {'200': {'content': {'application/json': {'schema': {'items': {'$ref': '#/components/schemas/app__schemas__Tenant'},
#                                                                                                                  'title': 'Response '
#                                                                                                                           'List '
#                                                                                                                           'Pending '
#                                                                                                                           'Tenant '
#                                                                                                                           'Invites '
#                                                                                                                           'Api '
#                                                                                                                           'V1 '
#                                                                                                                           'Tenants '
#                                                                                                                           'Pending '
#                                                                                                                           'Get',
#                                                                                                                  'type': 'array'}}},
#                                                                      'description': 'Successful '
#                                                                                     'Response'}},
#                                                'security': [{'Bearer Auth': []}],
#                                                'summary': 'List Pending Tenant '
#                                                           'Invites',
#                                                'tags': ['tenant']}},
#            '/api/v1/tenants/pending/{id}': {'delete': {'operationId': 'delete_pending_tenant_invite_api_v1_tenants_pending__id__delete',
#                                                        'parameters': [{'in': 'path',
#                                                                        'name': 'id',
#                                                                        'required': True,
#                                                                        'schema': {'format': 'uuid',
#                                                                                   'title': 'Id',
#                                                                                   'type': 'string'}}],
#                                                        'responses': {'200': {'content': {'application/json': {'schema': {}}},
#                                                                              'description': 'Successful '
#                                                                                             'Response'},
#                                                                      '422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}},
#                                                                              'description': 'Validation '
#                                                                                             'Error'}},
#                                                        'security': [{'Bearer Auth': []}],
#                                                        'summary': 'Delete '
#                                                                   'Pending '
#                                                                   'Tenant '
#                                                                   'Invite',
#                                                        'tags': ['tenant']}},
#            '/api/v1/tenants/pending/{tenant_id}/claim': {'post': {'operationId': 'claim_pending_tenant_invite_api_v1_tenants_pending__tenant_id__claim_post',
#                                                                   'parameters': [{'in': 'path',
#                                                                                   'name': 'tenant_id',
#                                                                                   'required': True,
#                                                                                   'schema': {'format': 'uuid',
#                                                                                              'title': 'Tenant '
#                                                                                                       'Id',
#                                                                                              'type': 'string'}}],
#                                                                   'responses': {'200': {'content': {'application/json': {'schema': {}}},
#                                                                                         'description': 'Successful '
#                                                                                                        'Response'},
#                                                                                 '422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}},
#                                                                                         'description': 'Validation '
#                                                                                                        'Error'}},
#                                                                   'security': [{'Bearer Auth': []}],
#                                                                   'summary': 'Claim '
#                                                                              'Pending '
#                                                                              'Tenant '
#                                                                              'Invite',
#                                                                   'tags': ['tenant']}},
#            '/api/v1/tenants/stats': {'get': {'deprecated': True,
#                                              'operationId': 'get_current_tenant_stats_api_v1_tenants_stats_get',
#                                              'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/TenantStats'}}},
#                                                                    'description': 'Successful '
#                                                                                   'Response'}},
#                                              'security': [{'API Key': []},
#                                                           {'Tenant ID': []},
#                                                           {'Bearer Auth': []}],
#                                              'summary': 'Get Current Tenant '
#                                                         'Stats',
#                                              'tags': ['tenant']}},
#            '/api/v1/usage-limits/': {'get': {'description': 'List out the '
#                                                             'configured usage '
#                                                             'limits for a '
#                                                             'given tenant.',
#                                              'operationId': 'list_usage_limits_api_v1_usage_limits__get',
#                                              'responses': {'200': {'content': {'application/json': {'schema': {'items': {'$ref': '#/components/schemas/UsageLimit'},
#                                                                                                                'title': 'Response '
#                                                                                                                         'List '
#                                                                                                                         'Usage '
#                                                                                                                         'Limits '
#                                                                                                                         'Api '
#                                                                                                                         'V1 '
#                                                                                                                         'Usage '
#                                                                                                                         'Limits  '
#                                                                                                                         'Get',
#                                                                                                                'type': 'array'}}},
#                                                                    'description': 'Successful '
#                                                                                   'Response'}},
#                                              'security': [{'API Key': []},
#                                                           {'Tenant ID': []},
#                                                           {'Bearer Auth': []}],
#                                              'summary': 'List Usage Limits',
#                                              'tags': ['usage-limits']},
#                                      'put': {'description': 'Create a new '
#                                                             'usage limit.',
#                                              'operationId': 'upsert_usage_limit_api_v1_usage_limits__put',
#                                              'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/UpsertUsageLimit'}}},
#                                                              'required': True},
#                                              'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/UsageLimit'}}},
#                                                                    'description': 'Successful '
#                                                                                   'Response'},
#                                                            '422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}},
#                                                                    'description': 'Validation '
#                                                                                   'Error'}},
#                                              'security': [{'API Key': []},
#                                                           {'Tenant ID': []},
#                                                           {'Bearer Auth': []}],
#                                              'summary': 'Upsert Usage Limit',
#                                              'tags': ['usage-limits']}},
#            '/api/v1/usage-limits/{usage_limit_id}': {'delete': {'description': 'Delete '
#                                                                                'a '
#                                                                                'specific '
#                                                                                'usage '
#                                                                                'limit.',
#                                                                 'operationId': 'delete_usage_limit_api_v1_usage_limits__usage_limit_id__delete',
#                                                                 'parameters': [{'in': 'path',
#                                                                                 'name': 'usage_limit_id',
#                                                                                 'required': True,
#                                                                                 'schema': {'format': 'uuid',
#                                                                                            'title': 'Usage '
#                                                                                                     'Limit '
#                                                                                                     'Id',
#                                                                                            'type': 'string'}}],
#                                                                 'responses': {'200': {'content': {'application/json': {'schema': {}}},
#                                                                                       'description': 'Successful '
#                                                                                                      'Response'},
#                                                                               '422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}},
#                                                                                       'description': 'Validation '
#                                                                                                      'Error'}},
#                                                                 'security': [{'API Key': []},
#                                                                              {'Tenant ID': []},
#                                                                              {'Bearer Auth': []}],
#                                                                 'summary': 'Delete '
#                                                                            'Usage '
#                                                                            'Limit',
#                                                                 'tags': ['usage-limits']}},
#            '/ok': {'get': {'operationId': 'ok_ok_get',
#                            'responses': {'200': {'content': {'application/json': {'schema': {}}},
#                                                  'description': 'Successful '
#                                                                 'Response'}},
#                            'summary': 'Ok'}}},
#  'servers': [{'description': 'LangSmith API endpoint.',
#               'url': 'https://api.smith.langchain.com'}]}

# %%
from langchain_text_splitters import RecursiveJsonSplitter

# %%
splitter = RecursiveJsonSplitter(max_chunk_size=300)

# %%
# Recursively split json data - If you need to access/manipulate the smaller json chunks
json_chunks = splitter.split_json(json_data=json_data)
pprint(json_chunks)
# Out:
# [{'info': {'title': 'LangSmith', 'version': '0.1.0'},
#   'openapi': '3.1.0',
#   'servers': [{'description': 'LangSmith API endpoint.',
#                'url': 'https://api.smith.langchain.com'}]},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'description': 'Get a '
#                                                                      'specific '
#                                                                      'session.',
#                                                       'operationId': 'read_tracer_session_api_v1_sessions__session_id__get',
#                                                       'summary': 'Read Tracer '
#                                                                  'Session',
#                                                       'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'security': [{'API Key': []},
#                                                                    {'Tenant ID': []},
#                                                                    {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'parameters': [{'in': 'path',
#                                                                       'name': 'session_id',
#                                                                       'required': True,
#                                                                       'schema': {'format': 'uuid',
#                                                                                  'title': 'Session '
#                                                                                           'Id',
#                                                                                  'type': 'string'}},
#                                                                      {'in': 'query',
#                                                                       'name': 'include_stats',
#                                                                       'required': False,
#                                                                       'schema': {'default': False,
#                                                                                  'title': 'Include '
#                                                                                           'Stats',
#                                                                                  'type': 'boolean'}},
#                                                                      {'in': 'header',
#                                                                       'name': 'accept',
#                                                                       'required': False,
#                                                                       'schema': {'anyOf': [{'type': 'string'},
#                                                                                            {'type': 'null'}],
#                                                                                  'title': 'Accept'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/TracerSession'}}},
#                                                                             'description': 'Successful '
#                                                                                            'Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}},
#                                                                             'description': 'Validation '
#                                                                                            'Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'description': 'Create '
#                                                                        'a new '
#                                                                        'session.',
#                                                         'operationId': 'update_tracer_session_api_v1_sessions__session_id__patch',
#                                                         'summary': 'Update '
#                                                                    'Tracer '
#                                                                    'Session',
#                                                         'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'parameters': [{'in': 'path',
#                                                                         'name': 'session_id',
#                                                                         'required': True,
#                                                                         'schema': {'format': 'uuid',
#                                                                                    'title': 'Session '
#                                                                                             'Id',
#                                                                                    'type': 'string'}}],
#                                                         'security': [{'API Key': []},
#                                                                      {'Tenant ID': []},
#                                                                      {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/TracerSessionUpdate'}}},
#                                                                         'required': True}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/TracerSessionWithoutVirtualFields'}}},
#                                                                               'description': 'Successful '
#                                                                                              'Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}},
#                                                                               'description': 'Validation '
#                                                                                              'Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'description': 'Delete '
#                                                                         'a '
#                                                                         'specific '
#                                                                         'session.',
#                                                          'operationId': 'delete_tracer_session_api_v1_sessions__session_id__delete',
#                                                          'summary': 'Delete '
#                                                                     'Tracer '
#                                                                     'Session',
#                                                          'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'parameters': [{'in': 'path',
#                                                                          'name': 'session_id',
#                                                                          'required': True,
#                                                                          'schema': {'format': 'uuid',
#                                                                                     'title': 'Session '
#                                                                                              'Id',
#                                                                                     'type': 'string'}}],
#                                                          'security': [{'API Key': []},
#                                                                       {'Tenant ID': []},
#                                                                       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'responses': {'200': {'content': {'application/json': {'schema': {}}},
#                                                                                'description': 'Successful '
#                                                                                               'Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}},
#                                                                                'description': 'Validation '
#                                                                                               'Error'}}}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'description': 'Get all sessions.',
#                                          'operationId': 'read_tracer_sessions_api_v1_sessions_get',
#                                          'security': [{'API Key': []},
#                                                       {'Tenant ID': []},
#                                                       {'Bearer Auth': []}],
#                                          'summary': 'Read Tracer Sessions',
#                                          'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'parameters': [{'in': 'query',
#                                                          'name': 'reference_free',
#                                                          'required': False,
#                                                          'schema': {'anyOf': [{'type': 'boolean'},
#                                                                               {'type': 'null'}],
#                                                                     'title': 'Reference '
#                                                                              'Free'}},
#                                                         {'in': 'query',
#                                                          'name': 'reference_dataset',
#                                                          'required': False,
#                                                          'schema': {'anyOf': [{'items': {'format': 'uuid',
#                                                                                          'type': 'string'},
#                                                                                'type': 'array'},
#                                                                               {'type': 'null'}],
#                                                                     'title': 'Reference '
#                                                                              'Dataset'}},
#                                                         {'in': 'query',
#                                                          'name': 'id',
#                                                          'required': False,
#                                                          'schema': {'anyOf': [{'items': {'format': 'uuid',
#                                                                                          'type': 'string'},
#                                                                                'type': 'array'},
#                                                                               {'type': 'null'}],
#                                                                     'title': 'Id'}},
#                                                         {'in': 'query',
#                                                          'name': 'name',
#                                                          'required': False,
#                                                          'schema': {'anyOf': [{'type': 'string'},
#                                                                               {'type': 'null'}],
#                                                                     'title': 'Name'}},
#                                                         {'in': 'query',
#                                                          'name': 'name_contains',
#                                                          'required': False,
#                                                          'schema': {'anyOf': [{'type': 'string'},
#                                                                               {'type': 'null'}],
#                                                                     'title': 'Name '
#                                                                              'Contains'}},
#                                                         {'in': 'query',
#                                                          'name': 'dataset_version',
#                                                          'required': False,
#                                                          'schema': {'anyOf': [{'type': 'string'},
#                                                                               {'type': 'null'}],
#                                                                     'title': 'Dataset '
#                                                                              'Version'}},
#                                                         {'in': 'query',
#                                                          'name': 'sort_by',
#                                                          'required': False,
#                                                          'schema': {'allOf': [{'$ref': '#/components/schemas/SessionSortableColumns'}],
#                                                                     'default': 'start_time',
#                                                                     'title': 'Sort '
#                                                                              'By'}},
#                                                         {'in': 'query',
#                                                          'name': 'sort_by_desc',
#                                                          'required': False,
#                                                          'schema': {'default': True,
#                                                                     'title': 'Sort '
#                                                                              'By '
#                                                                              'Desc',
#                                                                     'type': 'boolean'}},
#                                                         {'in': 'query',
#                                                          'name': 'sort_by_feedback_key',
#                                                          'required': False,
#                                                          'schema': {'anyOf': [{'type': 'string'},
#                                                                               {'type': 'null'}],
#                                                                     'title': 'Sort '
#                                                                              'By '
#                                                                              'Feedback '
#                                                                              'Key'}},
#                                                         {'in': 'query',
#                                                          'name': 'offset',
#                                                          'required': False,
#                                                          'schema': {'default': 0,
#                                                                     'minimum': 0,
#                                                                     'title': 'Offset',
#                                                                     'type': 'integer'}},
#                                                         {'in': 'query',
#                                                          'name': 'limit',
#                                                          'required': False,
#                                                          'schema': {'default': 100,
#                                                                     'maximum': 100,
#                                                                     'minimum': 1,
#                                                                     'title': 'Limit',
#                                                                     'type': 'integer'}},
#                                                         {'in': 'query',
#                                                          'name': 'facets',
#                                                          'required': False,
#                                                          'schema': {'default': False,
#                                                                     'title': 'Facets',
#                                                                     'type': 'boolean'}},
#                                                         {'in': 'header',
#                                                          'name': 'accept',
#                                                          'required': False,
#                                                          'schema': {'anyOf': [{'type': 'string'},
#                                                                               {'type': 'null'}],
#                                                                     'title': 'Accept'}}]}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'items': {'$ref': '#/components/schemas/TracerSession'},
#                                                                                                            'title': 'Response '
#                                                                                                                     'Read '
#                                                                                                                     'Tracer '
#                                                                                                                     'Sessions '
#                                                                                                                     'Api '
#                                                                                                                     'V1 '
#                                                                                                                     'Sessions '
#                                                                                                                     'Get',
#                                                                                                            'type': 'array'}}},
#                                                                'description': 'Successful '
#                                                                               'Response'}}}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}},
#                                                                'description': 'Validation '
#                                                                               'Error'}}}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'description': 'Create a new '
#                                                          'session.',
#                                           'operationId': 'create_tracer_session_api_v1_sessions_post',
#                                           'security': [{'API Key': []},
#                                                        {'Tenant ID': []},
#                                                        {'Bearer Auth': []}],
#                                           'summary': 'Create Tracer Session',
#                                           'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'parameters': [{'in': 'query',
#                                                           'name': 'upsert',
#                                                           'required': False,
#                                                           'schema': {'default': False,
#                                                                      'title': 'Upsert',
#                                                                      'type': 'boolean'}}]}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/TracerSessionCreate'}}},
#                                                           'required': True}}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/TracerSessionWithoutVirtualFields'}}},
#                                                                 'description': 'Successful '
#                                                                                'Response'}}}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}},
#                                                                 'description': 'Validation '
#                                                                                'Error'}}}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'description': 'Delete a specific '
#                                                            'session.',
#                                             'operationId': 'delete_tracer_sessions_api_v1_sessions_delete',
#                                             'security': [{'API Key': []},
#                                                          {'Tenant ID': []},
#                                                          {'Bearer Auth': []}],
#                                             'summary': 'Delete Tracer Sessions',
#                                             'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'parameters': [{'in': 'query',
#                                                             'name': 'session_ids',
#                                                             'required': True,
#                                                             'schema': {'items': {'format': 'uuid',
#                                                                                  'type': 'string'},
#                                                                        'title': 'Session '
#                                                                                 'Ids',
#                                                                        'type': 'array'}}]}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'responses': {'200': {'content': {'application/json': {'schema': {}}},
#                                                                   'description': 'Successful '
#                                                                                  'Response'},
#                                                           '422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}},
#                                                                   'description': 'Validation '
#                                                                                  'Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'description': 'Given '
#                                                                               'a '
#                                                                               'session, '
#                                                                               'a '
#                                                                               'number '
#                                                                               'K, '
#                                                                               'and '
#                                                                               '(optionally) '
#                                                                               'a '
#                                                                               'list '
#                                                                               'of '
#                                                                               'metadata '
#                                                                               'keys, '
#                                                                               'return '
#                                                                               'the '
#                                                                               'top '
#                                                                               'K '
#                                                                               'values '
#                                                                               'for '
#                                                                               'each '
#                                                                               'key.',
#                                                                'summary': 'Read '
#                                                                           'Tracer '
#                                                                           'Sessions '
#                                                                           'Runs '
#                                                                           'Metadata',
#                                                                'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'operationId': 'read_tracer_sessions_runs_metadata_api_v1_sessions__session_id__metadata_get',
#                                                                'security': [{'API Key': []},
#                                                                             {'Tenant ID': []},
#                                                                             {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'parameters': [{'in': 'path',
#                                                                                'name': 'session_id',
#                                                                                'required': True,
#                                                                                'schema': {'format': 'uuid',
#                                                                                           'title': 'Session '
#                                                                                                    'Id',
#                                                                                           'type': 'string'}},
#                                                                               {'in': 'query',
#                                                                                'name': 'metadata_keys',
#                                                                                'required': False,
#                                                                                'schema': {'anyOf': [{'items': {'type': 'string'},
#                                                                                                      'type': 'array'},
#                                                                                                     {'type': 'null'}],
#                                                                                           'title': 'Metadata '
#                                                                                                    'Keys'}},
#                                                                               {'in': 'query',
#                                                                                'name': 'start_time',
#                                                                                'required': False,
#                                                                                'schema': {'anyOf': [{'format': 'date-time',
#                                                                                                      'type': 'string'},
#                                                                                                     {'type': 'null'}],
#                                                                                           'title': 'Start '
#                                                                                                    'Time'}},
#                                                                               {'in': 'query',
#                                                                                'name': 'k',
#                                                                                'required': False,
#                                                                                'schema': {'default': 10,
#                                                                                           'minimum': 1,
#                                                                                           'title': 'K',
#                                                                                           'type': 'integer'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/RootModel_Dict_str__list_str___'}}},
#                                                                                      'description': 'Successful '
#                                                                                                     'Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}},
#                                                                                      'description': 'Validation '
#                                                                                                     'Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/setup': {'post': {'operationId': 'create_customers_and_get_stripe_setup_intent_api_v1_orgs_current_setup_post',
#                                                     'summary': 'Create '
#                                                                'Customers And '
#                                                                'Get Stripe '
#                                                                'Setup Intent',
#                                                     'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/setup': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/StripeSetupIntentResponse'}}},
#                                                                           'description': 'Successful '
#                                                                                          'Response'}},
#                                                     'security': [{'API Key': []},
#                                                                  {'Tenant ID': []},
#                                                                  {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current': {'get': {'operationId': 'get_organization_info_api_v1_orgs_current_get',
#                                              'summary': 'Get Organization Info',
#                                              'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Organization'}}},
#                                                                    'description': 'Successful '
#                                                                                   'Response'}},
#                                              'security': [{'API Key': []},
#                                                           {'Tenant ID': []},
#                                                           {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'operationId': 'get_dashboard_api_v1_orgs_current_dashboard_get',
#                                                        'security': [{'API Key': []},
#                                                                     {'Tenant ID': []},
#                                                                     {'Bearer Auth': []}],
#                                                        'summary': 'Get '
#                                                                   'Dashboard',
#                                                        'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'parameters': [{'in': 'query',
#                                                                        'name': 'type',
#                                                                        'required': True,
#                                                                        'schema': {'$ref': '#/components/schemas/OrganizationDashboardType'}},
#                                                                       {'in': 'query',
#                                                                        'name': 'color_scheme',
#                                                                        'required': True,
#                                                                        'schema': {'anyOf': [{'$ref': '#/components/schemas/OrganizationDashboardColorScheme'},
#                                                                                             {'type': 'null'}],
#                                                                                   'title': 'Color '
#                                                                                            'Scheme'}}]}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/OrganizationDashboardSchema'}}},
#                                                                              'description': 'Successful '
#                                                                                             'Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}},
#                                                                              'description': 'Validation '
#                                                                                             'Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'operationId': 'on_payment_method_created_api_v1_orgs_current_payment_method_post',
#                                                              'summary': 'On '
#                                                                         'Payment '
#                                                                         'Method '
#                                                                         'Created',
#                                                              'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/StripePaymentInformation'}}},
#                                                                              'required': True}}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {}}},
#                                                                                    'description': 'Successful '
#                                                                                                   'Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}},
#                                                                                    'description': 'Validation '
#                                                                                                   'Error'}},
#                                                              'security': [{'API Key': []},
#                                                                           {'Tenant ID': []},
#                                                                           {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'operationId': 'change_payment_plan_api_v1_orgs_current_plan_post',
#                                                    'summary': 'Change Payment '
#                                                               'Plan',
#                                                    'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/ChangePaymentPlanSchema'}}},
#                                                                    'required': True}}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {}}},
#                                                                          'description': 'Successful '
#                                                                                         'Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}},
#                                                                          'description': 'Validation '
#                                                                                         'Error'}},
#                                                    'security': [{'API Key': []},
#                                                                 {'Tenant ID': []},
#                                                                 {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/api-key': {'get': {'description': 'Get the current '
#                                                        "tenant's API keys",
#                                         'operationId': 'get_api_keys_api_v1_api_key_get',
#                                         'summary': 'Get Api Keys',
#                                         'tags': ['api-key']}}}},
#  {'paths': {'/api/v1/api-key': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'items': {'$ref': '#/components/schemas/APIKeyGetResponse'},
#                                                                                                           'title': 'Response '
#                                                                                                                    'Get '
#                                                                                                                    'Api '
#                                                                                                                    'Keys '
#                                                                                                                    'Api '
#                                                                                                                    'V1 '
#                                                                                                                    'Api '
#                                                                                                                    'Key '
#                                                                                                                    'Get',
#                                                                                                           'type': 'array'}}},
#                                                               'description': 'Successful '
#                                                                              'Response'}}}}}},
#  {'paths': {'/api/v1/api-key': {'get': {'security': [{'API Key': []},
#                                                      {'Tenant ID': []},
#                                                      {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/api-key': {'post': {'description': 'Generate an api key '
#                                                         'for the user',
#                                          'operationId': 'generate_api_key_api_v1_api_key_post',
#                                          'summary': 'Generate Api Key',
#                                          'tags': ['api-key']}}}},
#  {'paths': {'/api/v1/api-key': {'post': {'requestBody': {'content': {'application/json': {'schema': {'allOf': [{'$ref': '#/components/schemas/APIKeyCreateRequest'}],
#                                                                                                      'default': {'description': 'Default '
#                                                                                                                                 'API '
#                                                                                                                                 'key',
#                                                                                                                  'read_only': False},
#                                                                                                      'title': 'Payload'}}}}}}}},
#  {'paths': {'/api/v1/api-key': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/APIKeyCreateResponse'}}},
#                                                                'description': 'Successful '
#                                                                               'Response'}}}}}},
#  {'paths': {'/api/v1/api-key': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}},
#                                                                'description': 'Validation '
#                                                                               'Error'}},
#                                          'security': [{'API Key': []},
#                                                       {'Tenant ID': []},
#                                                       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/api-key/{api_key_id}': {'delete': {'description': 'Delete '
#                                                                        'an api '
#                                                                        'key '
#                                                                        'for '
#                                                                        'the '
#                                                                        'user',
#                                                         'operationId': 'delete_api_key_api_v1_api_key__api_key_id__delete',
#                                                         'security': [{'API Key': []},
#                                                                      {'Tenant ID': []},
#                                                                      {'Bearer Auth': []}],
#                                                         'summary': 'Delete Api '
#                                                                    'Key',
#                                                         'tags': ['api-key']}}}},
#  {'paths': {'/api/v1/api-key/{api_key_id}': {'delete': {'parameters': [{'in': 'path',
#                                                                         'name': 'api_key_id',
#                                                                         'required': True,
#                                                                         'schema': {'format': 'uuid',
#                                                                                    'title': 'Api '
#                                                                                             'Key '
#                                                                                             'Id',
#                                                                                    'type': 'string'}}]}}}},
#  {'paths': {'/api/v1/api-key/{api_key_id}': {'delete': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/APIKeyGetResponse'}}},
#                                                                               'description': 'Successful '
#                                                                                              'Response'}}}}}},
#  {'paths': {'/api/v1/api-key/{api_key_id}': {'delete': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}},
#                                                                               'description': 'Validation '
#                                                                                              'Error'}}}}}},
#  {'paths': {'/api/v1/examples/{example_id}': {'get': {'description': 'Get a '
#                                                                      'specific '
#                                                                      'example.',
#                                                       'operationId': 'read_example_api_v1_examples__example_id__get',
#                                                       'security': [{'API Key': []},
#                                                                    {'Tenant ID': []},
#                                                                    {'Bearer Auth': []}],
#                                                       'summary': 'Read Example',
#                                                       'tags': ['examples']}}}},
#  {'paths': {'/api/v1/examples/{example_id}': {'get': {'parameters': [{'in': 'path',
#                                                                       'name': 'example_id',
#                                                                       'required': True,
#                                                                       'schema': {'format': 'uuid',
#                                                                                  'title': 'Example '
#                                                                                           'Id',
#                                                                                  'type': 'string'}},
#                                                                      {'description': 'Only '
#                                                                                      'modifications '
#                                                                                      'made '
#                                                                                      'on '
#                                                                                      'or '
#                                                                                      'before '
#                                                                                      'this '
#                                                                                      'time '
#                                                                                      'are '
#                                                                                      'included. '
#                                                                                      'If '
#                                                                                      'None, '
#                                                                                      'the '
# ...
#                                                                                                                       'type': 'string'},
#                                                                                                                      {'type': 'null'}],
#                                                                                                            'title': 'Reference '
#                                                                                                                     'Dataset '
#                                                                                                                     'Id'}}}}}},
#  {'components': {'schemas': {'TracerSessionWithoutVirtualFields': {'properties': {'last_run_start_time_live': {'anyOf': [{'format': 'date-time',
#                                                                                                                           'type': 'string'},
#                                                                                                                          {'type': 'null'}],
#                                                                                                                'title': 'Last '
#                                                                                                                         'Run '
#                                                                                                                         'Start '
#                                                                                                                         'Time '
#                                                                                                                         'Live'},
#                                                                                   'tenant_id': {'format': 'uuid',
#                                                                                                 'title': 'Tenant '
#                                                                                                          'Id',
#                                                                                                 'type': 'string'}}}}}},
#  {'components': {'schemas': {'TracerSessionWithoutVirtualFields': {'description': 'TracerSession '
#                                                                                   'schema.',
#                                                                    'required': ['id',
#                                                                                 'tenant_id'],
#                                                                    'title': 'TracerSessionWithoutVirtualFields',
#                                                                    'type': 'object'}}}},
#  {'components': {'schemas': {'UpdateRepoRequest': {'properties': {'description': {'anyOf': [{'type': 'string'},
#                                                                                             {'type': 'null'}],
#                                                                                   'title': 'Description'},
#                                                                   'readme': {'anyOf': [{'type': 'string'},
#                                                                                        {'type': 'null'}],
#                                                                              'title': 'Readme'}}}}}},
#  {'components': {'schemas': {'UpdateRepoRequest': {'properties': {'is_public': {'anyOf': [{'type': 'boolean'},
#                                                                                           {'type': 'null'}],
#                                                                                 'title': 'Is '
#                                                                                          'Public'},
#                                                                   'tags': {'anyOf': [{'items': {'type': 'string'},
#                                                                                       'type': 'array'},
#                                                                                      {'type': 'null'}],
#                                                                            'title': 'Tags'}}}}}},
#  {'components': {'schemas': {'UpdateRepoRequest': {'description': 'Fields to '
#                                                                   'update a '
#                                                                   'repo',
#                                                    'properties': {'is_archived': {'anyOf': [{'type': 'boolean'},
#                                                                                             {'type': 'null'}],
#                                                                                   'title': 'Is '
#                                                                                            'Archived'}},
#                                                    'title': 'UpdateRepoRequest',
#                                                    'type': 'object'}}}},
#  {'components': {'schemas': {'UpsertUsageLimit': {'properties': {'id': {'format': 'uuid',
#                                                                         'title': 'Id',
#                                                                         'type': 'string'},
#                                                                  'limit_type': {'$ref': '#/components/schemas/UsageLimitType'},
#                                                                  'limit_value': {'title': 'Limit '
#                                                                                           'Value',
#                                                                                  'type': 'integer'}},
#                                                   'type': 'object'}}}},
#  {'components': {'schemas': {'UpsertUsageLimit': {'description': 'Request body '
#                                                                  'for creating '
#                                                                  'or updating '
#                                                                  'a usage '
#                                                                  'limit.',
#                                                   'required': ['limit_type',
#                                                                'limit_value'],
#                                                   'title': 'UpsertUsageLimit'}}}},
#  {'components': {'schemas': {'UsageLimit': {'properties': {'id': {'format': 'uuid',
#                                                                   'title': 'Id',
#                                                                   'type': 'string'},
#                                                            'limit_type': {'$ref': '#/components/schemas/UsageLimitType'},
#                                                            'limit_value': {'title': 'Limit '
#                                                                                     'Value',
#                                                                            'type': 'integer'}}}}}},
#  {'components': {'schemas': {'UsageLimit': {'properties': {'created_at': {'format': 'date-time',
#                                                                           'title': 'Created '
#                                                                                    'At',
#                                                                           'type': 'string'},
#                                                            'tenant_id': {'format': 'uuid',
#                                                                          'title': 'Tenant '
#                                                                                   'Id',
#                                                                          'type': 'string'},
#                                                            'updated_at': {'format': 'date-time',
#                                                                           'title': 'Updated '
#                                                                                    'At',
#                                                                           'type': 'string'}}}}}},
#  {'components': {'schemas': {'UsageLimit': {'description': 'Usage limit model.',
#                                             'required': ['limit_type',
#                                                          'limit_value',
#                                                          'tenant_id',
#                                                          'created_at',
#                                                          'updated_at'],
#                                             'title': 'UsageLimit',
#                                             'type': 'object'}}}},
#  {'components': {'schemas': {'UsageLimitType': {'const': 'monthly_traces',
#                                                 'description': 'Type of usage '
#                                                                'limit.',
#                                                 'title': 'UsageLimitType',
#                                                 'type': 'string'}}}},
#  {'components': {'schemas': {'ValidationError': {'properties': {'loc': {'items': {'anyOf': [{'type': 'string'},
#                                                                                             {'type': 'integer'}]},
#                                                                         'title': 'Location',
#                                                                         'type': 'array'},
#                                                                 'msg': {'title': 'Message',
#                                                                         'type': 'string'},
#                                                                 'type': {'title': 'Error '
#                                                                                   'Type',
#                                                                          'type': 'string'}},
#                                                  'type': 'object'}}}},
#  {'components': {'schemas': {'ValidationError': {'required': ['loc',
#                                                               'msg',
#                                                               'type'],
#                                                  'title': 'ValidationError'}}}},
#  {'components': {'schemas': {'app__hub__crud__tenants__Tenant': {'properties': {'created_at': {'format': 'date-time',
#                                                                                                'title': 'Created '
#                                                                                                         'At',
#                                                                                                'type': 'string'},
#                                                                                 'display_name': {'title': 'Display '
#                                                                                                           'Name',
#                                                                                                  'type': 'string'},
#                                                                                 'id': {'format': 'uuid',
#                                                                                        'title': 'Id',
#                                                                                        'type': 'string'}}}}}},
#  {'components': {'schemas': {'app__hub__crud__tenants__Tenant': {'properties': {'tenant_handle': {'anyOf': [{'type': 'string'},
#                                                                                                             {'type': 'null'}],
#                                                                                                   'title': 'Tenant '
#                                                                                                            'Handle'}},
#                                                                  'required': ['id',
#                                                                               'display_name',
#                                                                               'created_at'],
#                                                                  'title': 'Tenant',
#                                                                  'type': 'object'}}}},
#  {'components': {'schemas': {'app__schemas__Tenant': {'properties': {'id': {'format': 'uuid',
#                                                                             'title': 'Id',
#                                                                             'type': 'string'},
#                                                                      'organization_id': {'anyOf': [{'format': 'uuid',
#                                                                                                     'type': 'string'},
#                                                                                                    {'type': 'null'}],
#                                                                                          'title': 'Organization '
#                                                                                                   'Id'}}}}}},
#  {'components': {'schemas': {'app__schemas__Tenant': {'properties': {'created_at': {'format': 'date-time',
#                                                                                     'title': 'Created '
#                                                                                              'At',
#                                                                                     'type': 'string'},
#                                                                      'display_name': {'title': 'Display '
#                                                                                                'Name',
#                                                                                       'type': 'string'},
#                                                                      'is_personal': {'title': 'Is '
#                                                                                               'Personal',
#                                                                                      'type': 'boolean'}}}}}},
#  {'components': {'schemas': {'app__schemas__Tenant': {'properties': {'tenant_handle': {'anyOf': [{'type': 'string'},
#                                                                                                  {'type': 'null'}],
#                                                                                        'title': 'Tenant '
#                                                                                                 'Handle'}},
#                                                       'required': ['id',
#                                                                    'created_at',
#                                                                    'display_name',
#                                                                    'is_personal'],
#                                                       'title': 'Tenant',
#                                                       'type': 'object'}}}},
#  {'components': {'schemas': {'app__schemas__Tenant': {'description': 'Tenant '
#                                                                      'schema.'}},
#                  'securitySchemes': {'API Key': {'in': 'header',
#                                                  'name': 'X-API-Key',
#                                                  'type': 'apiKey'},
#                                      'Tenant ID': {'in': 'header',
#                                                    'name': 'X-Tenant-Id',
#                                                    'type': 'apiKey'}}}},
#  {'components': {'securitySchemes': {'Bearer Auth': {'scheme': 'bearer',
#                                                      'type': 'http'}}}}]

# %%
# The splitter can also output documents
docs = splitter.create_documents(texts=[json_data])

# or a list of strings
texts = splitter.split_text(json_data=json_data)

print(texts[0])
print(texts[1])
# Out:
# {"openapi": "3.1.0", "info": {"title": "LangSmith", "version": "0.1.0"}, "servers": [{"url": "https://api.smith.langchain.com", "description": "LangSmith API endpoint."}]}
# {"paths": {"/api/v1/sessions/{session_id}": {"get": {"tags": ["tracer-sessions"], "summary": "Read Tracer Session", "description": "Get a specific session.", "operationId": "read_tracer_session_api_v1_sessions__session_id__get"}}}}

# %%
# Let's look at the size of the chunks
print([len(text) for text in texts][:10])

# Reviewing one of these chunks that was bigger we see there is a list object there
print(texts[3])
# Out:
# [171, 231, 126, 469, 210, 213, 237, 271, 191, 232]
# {"paths": {"/api/v1/sessions/{session_id}": {"get": {"parameters": [{"name": "session_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Session Id"}}, {"name": "include_stats", "in": "query", "required": false, "schema": {"type": "boolean", "default": false, "title": "Include Stats"}}, {"name": "accept", "in": "header", "required": false, "schema": {"anyOf": [{"type": "string"}, {"type": "null"}], "title": "Accept"}}]}}}}

# %%
# The json splitter by default does not split lists
# the following will preprocess the json and convert list to dict with index:item as key:val pairs
texts = splitter.split_text(json_data=json_data, convert_lists=True)

# %%
# Let's look at the size of the chunks. Now they are all under the max
print([len(text) for text in texts][:10])
# Out:
# [171, 231, 126, 469, 210, 213, 237, 271, 191, 232]

# %%
# The list has been converted to a dict, but retains all the needed contextual information even if split into many chunks
print(texts[3])
# Out:
# {"paths": {"/api/v1/sessions/{session_id}": {"get": {"parameters": [{"name": "session_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Session Id"}}, {"name": "include_stats", "in": "query", "required": false, "schema": {"type": "boolean", "default": false, "title": "Include Stats"}}, {"name": "accept", "in": "header", "required": false, "schema": {"anyOf": [{"type": "string"}, {"type": "null"}], "title": "Accept"}}]}}}}

# %%
# We can also look at the documents
docs[1]
# Out:
# Document(page_content='{"paths": {"/api/v1/sessions/{session_id}": {"get": {"tags": ["tracer-sessions"], "summary": "Read Tracer Session", "description": "Get a specific session.", "operationId": "read_tracer_session_api_v1_sessions__session_id__get"}}}}')
